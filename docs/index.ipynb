# %% [markdown]
# # idendrogram
#
# idendrogram helps you create nicer, interactive visualizations of hierarchical clustering trees (a.k.a. dendrograms) from clustering outputs generated by your preferred hierarchical clustering library (SciPy, Scikit-learn or HDBSCAN) in your preferred python visualization library (Altair, Plotly or Matplotlib)
#
# It also supports bi-directional Streamlit integration via a custom D3-powered component.

# %% [markdown]
# ## Gallery
#
# idendrogram supports custom tooltips, customization of colors, leaf labels, rotation and nearly any other attribute of nodes and links in dendrograms.
#
# Be sure to also check out interactive Streamlit demos!
#
# #### Customizable interactive tooltips
# <img src="gallery/custom-tooltips.png" alt="drawing" width="600"/>
#
# #### Customizable node radii
# <img src="gallery/custom-radii.png" alt="drawing" width="600"/>
#
# #### Full control of colors
# <img src="gallery/custom-colors.png" alt="drawing" width="600"/>
#
# #### Customization of pretty much any aspect
# <img src="gallery/custom-labels.png" alt="drawing" width="600"/>
# <img src="gallery/custom-looks.png" alt="drawing" width="600"/>
# <img src="gallery/custom-rotation.png" alt="drawing" width="600"/>

# %% [markdown]
# ## Installation
#
# To use the main package:
#
# ```pip install idendrogram```
#
# To install recommended visualization backends as well:
#
# ```pip install idendrogram[altair plotly]```
#
# To install the bi-directional Streamlit component:
#
# ```pip install idendrogram-streamlit-component```

# %% [markdown]
# # Usage
#
# See [Getting Started](getting-started) for usage examples.
